# %%
import pandas as pd
import numpy as np

data= pd.read_csv('fraud_detection_credit_card_small.csv')
data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0     1045211   2020-03-09 15:09:26      577588686219
# 1      547406   2019-08-22 15:49:01    30376238035123
# 2      110142   2019-03-04 01:34:16  4658490815480264
# 3     1285953   2020-06-16 20:04:38  3514897282719543
# 4      271705   2019-05-14 05:54:48  6011381817520024
#
#                                       merchant        category     amt  \
# 0                              fraud_Towne LLC        misc_pos  194.51
# 1                            fraud_Friesen Ltd  health_fitness   52.32
# 2                               fraud_Mohr Inc    shopping_pos    6.53
# 3                      fraud_Gaylord-Powlowski            home    7.33
# 4  fraud_Christiansen, Goyette and Schamberger   gas_transport   64.29
#
#      first        last gender                        street  ...  merch_long  \
# 0    James  Strickland      M            25454 Leonard Lake  ...  -78.865012
# ...

# %%
data=df.rename(columns={
     "Unnamed: 0": "id",
    "trans_date_trans_time": "fecha_hora_transaccion",
    "cc_num": "num_tarjeta",
    "merchant": "nombre_comercio",
    "category": "categoria_comercio",
    "amt": "monto_transaccion",
    "first": "nombre_cliente",
    "last": "apellido_cliente",
    "gender": "genero",
    "street": "direccion_cliente",
    "city": "ciudad_cliente",
    "state": "estado_cliente",
    "zip": "codigo_postal_cliente",
    "lat": "latitud_cliente",
    "long": "longitud_cliente",
    "city_pop": "poblacion_ciudad",
    "job": "ocupacion_cliente",
    "dob": "fecha_nacimiento_cliente",
    "trans_num": "num_transaccion",
    "unix_time": "timestamp_unix",
    "merch_lat": "latitud_comercio",
    "merch_long": "longitud_comercio",
    "is_fraud": "fraude",  # Variable objetivo
    "merch_zipcode": "codigo_postal_comercio",
    "Merchant_Category": "categoria_comercio_detallada",
    "Transaction_Type": "tipo_transaccion",
    "Customer_Satisfaction_Score": "satisfaccion_cliente",
    "Transaction_Time": "hora_transaccion",
    "Customer_Age": "edad_cliente",
    "Payment_Method": "metodo_pago",
    "Loyalty_Points_Earned": "puntos_lealtad_ganados"
})
data.head()
# Out:
#         id fecha_hora_transaccion       num_tarjeta  \
# 0  1045211    2020-03-09 15:09:26      577588686219
# 1   547406    2019-08-22 15:49:01    30376238035123
# 2   110142    2019-03-04 01:34:16  4658490815480264
# 3  1285953    2020-06-16 20:04:38  3514897282719543
# 4   271705    2019-05-14 05:54:48  6011381817520024
#
#                                nombre_comercio categoria_comercio  \
# 0                              fraud_Towne LLC           misc_pos
# 1                            fraud_Friesen Ltd     health_fitness
# 2                               fraud_Mohr Inc       shopping_pos
# 3                      fraud_Gaylord-Powlowski               home
# 4  fraud_Christiansen, Goyette and Schamberger      gas_transport
#
#    monto_transaccion nombre_cliente apellido_cliente genero  \
# 0             194.51          James       Strickland      M
# 1              52.32        Cynthia            Davis      F
# 2               6.53           Tara         Richards      F
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id                            100000 non-null  int64
#  1   fecha_hora_transaccion        100000 non-null  object
#  2   num_tarjeta                   100000 non-null  int64
#  3   nombre_comercio               100000 non-null  object
#  4   categoria_comercio            100000 non-null  object
#  5   monto_transaccion             100000 non-null  float64
#  6   nombre_cliente                100000 non-null  object
#  7   apellido_cliente              100000 non-null  object
#  8   genero                        100000 non-null  object
#  9   direccion_cliente             100000 non-null  object
#  10  ciudad_cliente                100000 non-null  object
#  11  estado_cliente                100000 non-null  object
# ...

# %%
data.shape
# Out:
# (100000, 31)

# %%
data.isnull().sum()
# Out:
# id                                  0
# fecha_hora_transaccion              0
# num_tarjeta                         0
# nombre_comercio                     0
# categoria_comercio                  0
# monto_transaccion                   0
# nombre_cliente                      0
# apellido_cliente                    0
# genero                              0
# direccion_cliente                   0
# ciudad_cliente                      0
# estado_cliente                      0
# codigo_postal_cliente               0
# latitud_cliente                     0
# longitud_cliente                    0
# poblacion_ciudad                    0
# ocupacion_cliente                   0
# fecha_nacimiento_cliente            0
# num_transaccion                     0
# timestamp_unix                      0
# latitud_comercio                    0
# longitud_comercio                   0
# fraude                              0
# codigo_postal_comercio          15176
# categoria_comercio_detallada        0
# ...

# %%
data.describe()
# Out:
#                  id   num_tarjeta  monto_transaccion  codigo_postal_cliente  \
# count  1.000000e+05  1.000000e+05       100000.00000          100000.000000
# mean   6.496177e+05  4.144106e+17           70.09797           48877.432690
# std    3.738727e+05  1.304972e+18          141.31813           26889.271339
# min    1.300000e+01  6.041621e+10            1.00000            1257.000000
# 25%    3.259925e+05  1.800400e+14            9.63750           26237.000000
# 50%    6.494685e+05  3.518759e+15           47.56000           48174.000000
# 75%    9.735372e+05  4.642255e+15           82.84000           72042.000000
# max    1.296673e+06  4.992346e+18         9092.75000           99783.000000
#
#        latitud_cliente  longitud_cliente  poblacion_ciudad  timestamp_unix  \
# count    100000.000000     100000.000000      1.000000e+05    1.000000e+05
# mean         38.545307        -90.281210      8.926183e+04    1.349288e+09
# ...

# %%
print(df.dtypes)
# Out:
# Unnamed: 0                       int64
# trans_date_trans_time           object
# cc_num                           int64
# merchant                        object
# category                        object
# amt                            float64
# first                           object
# last                            object
# gender                          object
# street                          object
# city                            object
# state                           object
# zip                              int64
# lat                            float64
# long                           float64
# city_pop                         int64
# job                             object
# dob                             object
# trans_num                       object
# unix_time                        int64
# merch_lat                      float64
# merch_long                     float64
# is_fraud                         int64
# merch_zipcode                  float64
# ...

# %%
data["hora_transaccion"] = pd.to_datetime(data["hora_transaccion"], format="%H:%M").dt.hour * 60 + pd.to_datetime(data["hora_transaccion"], format="%H:%M").dt.minute

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la correlación
correlation_matrix = data[["monto_transaccion", "poblacion_ciudad", "edad_cliente",
                          "hora_transaccion", "satisfaccion_cliente",
                          "puntos_lealtad_ganados", "fraude"]].corr()

# Crear un heatmap de correlación
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Mapa de correlación entre variables y fraude")
plt.show()
